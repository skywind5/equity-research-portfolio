# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.valuation import dcf_valuation

fcf = 40000000000  # 40B
growth_rate = 0.08
discount_rate = 0.10
terminal_growth = 0.03

value = dcf_valuation(fcf, growth_rate, discount_rate, terminal_growth)
value

shares_outstanding = 2.5e9  # approx
intrinsic_price = value / shares_outstanding
intrinsic_price
# Out:
# 290.5309446856674
